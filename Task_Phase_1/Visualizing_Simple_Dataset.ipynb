# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris_data = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

# %%
iris_data.shape
# Out:
# (150, 5)

# %%
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.scatter(iris_data["petal_length"],iris_data["petal_width"])
plt.title("Relationship Between petal length and width")
plt.xlabel("patel length")
plt.ylabel("patel width")
# Out:
# Text(0, 0.5, 'patel width')

# %%
plt.scatter(iris_data["sepal_length"],iris_data["sepal_width"])
plt.title("Relationship Between sepal length and width")
plt.xlabel("sepal length")
plt.ylabel("sepal width")
# Out:
# Text(0, 0.5, 'sepal width')

# %%
sns.histplot(iris_data["petal_length"])
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(iris_data["petal_width"])
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(iris_data["sepal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris_data["sepal_width"])
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
plt.boxplot(iris_data["petal_length"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209b0f19d10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x209b0f19f90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x209b0f19bd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x209b0f1a210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209b0f1a350>],
#  'means': []}

# %%
plt.boxplot(iris_data["petal_width"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209b54bc550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x209b54bc7d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x209b54bc410>],
#  'medians': [<matplotlib.lines.Line2D at 0x209b54bca50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209b54bcb90>],
#  'means': []}

# %%
plt.boxplot(iris_data["sepal_length"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209b54e7890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x209b54e7b10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x209b54e7750>],
#  'medians': [<matplotlib.lines.Line2D at 0x209b54e7d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209b54e7ed0>],
#  'means': []}

# %%
plt.boxplot(iris_data["sepal_width"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209b5663b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x209b5663d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x209b56639d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x209b5690050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209b5690190>],
#  'means': []}

# %%
for column in iris_data.drop("species", axis=1).columns:
    Q1 = iris_data[column].quantile(0.25)
    Q3 = iris_data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = iris_data[(iris_data[column] < lower_bound) | (iris_data[column] > upper_bound)]
    if not outliers.empty:
        print(f"Outliers in '{column}':")
        print(outliers[[column, 'species']])
    else:
        print(f"No outliers found in '{column}'.")
# Out:
# No outliers found in 'sepal_length'.
# Outliers in 'sepal_width':
#     sepal_width     species
# 15          4.4      setosa
# 32          4.1      setosa
# 33          4.2      setosa
# 60          2.0  versicolor
# No outliers found in 'petal_length'.
# No outliers found in 'petal_width'.
